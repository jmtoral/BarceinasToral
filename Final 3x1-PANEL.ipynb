# %%
# %matplotlib inline

import pandas as pd

# these will be useful later
import numpy  as np
from matplotlib import pyplot as plt

# %%
x31_13=pd.read_csv("hom_3x1_13pan.csv")
x31_14=pd.read_csv("hom_3x1_14pan.csv")
x31_14.head()
# Out:
#      id  year         ENTIDAD       MUNICIPIO  hom_rate  \
# 0  1001  2014  AGUASCALIENTES  AGUASCALIENTES  3.889537
# 1  1002  2014  AGUASCALIENTES        ASIENTOS  0.000000
# 2  1003  2014  AGUASCALIENTES        CALVILLO  3.694399
# 3  1004  2014  AGUASCALIENTES           COSIO  0.000000
# 4  1005  2014  AGUASCALIENTES     JESUS MARIA  6.024701
#
#    Servicios Comunitarios  Infraestructura  Proyectos Productivos  Total 3x1
# 0                       1                4                      1          6
# 1                       2                6                      1          9
# 2                       3                2                      5         10
# 3                       2                3                      0          5
# 4                       0                0                      2          2

# %%
tot3x1pan = pd.concat([x31_13,x31_14])

# %%
tot3x1pan.head(100000)
# Out:
#         id  year          ENTIDAD                     MUNICIPIO   hom_rate  \
# 0     1001  2013   AGUASCALIENTES                AGUASCALIENTES   2.383910
# 1     1002  2013   AGUASCALIENTES                      ASIENTOS  10.990943
# 2     1003  2013   AGUASCALIENTES                      CALVILLO   0.000000
# 3     1004  2013   AGUASCALIENTES                         COSIO   0.000000
# 4     1006  2013   AGUASCALIENTES           PABELLON DE ARTEAGA   2.388801
# 5     1007  2013   AGUASCALIENTES               RINCON DE ROMOS   4.068679
# 6     1008  2013   AGUASCALIENTES            SAN JOSE DE GRACIA   0.000000
# 7     1009  2013   AGUASCALIENTES                      TEPEZALA   0.000000
# 8     2001  2013  BAJA CALIFORNIA                      ENSENADA  10.282468
# 9     2004  2013  BAJA CALIFORNIA                       TIJUANA  31.544872
# 10    4001  2013         CAMPECHE                       CALKINI   1.890717
# ...

# %%
tot3x1pan=tot3x1pan.dropna()

# %%
tot3x1pan.to_csv('total_hom_3x1pan.csv')
